# %%
# 1. The Calculator App

# Objective: The aim of this assignment is to build a basic calculator that can 
# perform addition, subtraction, multiplication, and division.

# Task 1: Create functions for each arithmetic operation.

# Task 2: Use inputs to ask the user what operation they want to perform, and 
# what numbers they want to use.

# Task 3: Ensure your code can handle division by zero and other potential errors. 
# So if you divide by 0, there is error handling set up to prevent an error from 
# showing in the console.

# %%
# Task 1:
# Addition
def add(a, b):
    return a + b

# Subtraction
def sub(a, b):
    return a - b

# Multiplication
def mult(a, b):
    return a * b

# Division
def divi(a, b):
    return a / b

def calculator():
# Task 2:
    while True:
        print("\nBasic Calculator")
        print("Operations: ")
        print("[A]dd")
        print("[S]ubtract")
        print("[M]ultiply")
        print("[D]ivide")
        print("[E]xit")
        operation = input("Choose an operation: [A],[S],[M],[D],[E]")

        if operation.upper() == "A":
            a = float(input("Enter the first number: "))
            # print(f"You entered: {a}")
            b = float(input("Enter the number to add: "))
            # print(f"You entered: {b}")
            result = add(a, b)
            print(f"The result of {a} + {b} = {result:.2f}")
        elif operation.upper() == "S":
            a = float(input("Enter the first number: "))
            # print(f"You entered: {a}")
            b = float(input("Enter the number to subtract: "))
            # print(f"You entered: {b}")
            result = sub(a, b)
            print(f"The result of {a} - {b} = {result:.2f}")
        elif operation.upper() == "M":
            a = float(input("Enter the first number: "))
            # print(f"You entered: {a}")
            b = float(input("Enter the number to multiply by: "))
            # print(f"You entered: {b}")
            result = mult(a, b)
            print(f"The result of {a} * {b} = {result:.2f}")
        elif operation.upper() == "D":
            a = float(input("Enter the first number: "))
            # print(f"You entered: {a}")
            b = float(input("Enter the number to divide by: "))
            # print(f"You entered: {b}")
    # Task 3:         
            try:
                if a or b != 0:
                    result = divi(a, b)
                    print(f"The result of {a} / {b} = {result:.2f}")
            except (ZeroDivisionError, ValueError):
                print("Please enter a number greater than 0.")
        elif operation.upper() == "E":
            print("\nGlorious Calculations")
            break
        else:
            print("Invalid operation. Please try again.")

calculator()
# Out:
# Basic Calculator
# Operations:
# [A]dd
# [S]ubtract
# [M]ultiply
# [D]ivide
# [E]xit
# The result of 1.0 + 2.0 = 3.00
#
# Basic Calculator
# Operations:
# [A]dd
# [S]ubtract
# [M]ultiply
# [D]ivide
# [E]xit
# The result of 3.0 - 2.0 = 1.00
#
# Basic Calculator
# Operations:
# [A]dd
# [S]ubtract
# [M]ultiply
# [D]ivide
# [E]xit
# The result of 2.0 * 3.0 = 6.00
#
# Basic Calculator
# Operations:
# [A]dd
# [S]ubtract
# [M]ultiply
# [D]ivide
# [E]xit
# The result of 6.0 / 3.0 = 2.00
#
# Basic Calculator
# Operations:
# [A]dd
# [S]ubtract
# [M]ultiply
# [D]ivide
# [E]xit
# Please enter a number greater than 0.
#
# Basic Calculator
# Operations:
# [A]dd
# [S]ubtract
# [M]ultiply
# [D]ivide
# [E]xit
#
# Glorious Calculations
